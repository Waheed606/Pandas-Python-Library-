# %%
import pandas as pd

# %%
data=pd.read_csv("../sales_data.csv")

# %%
data
# Out:
#       flag gender        education  house_val     age online customer_psy  \
# 0        Y      M          4. Grad     756460   1_Unk      N            B
# 1        N      F          3. Bach     213171   7_>65      N            E
# 2        N      M  2. Some College     111147  2_<=25      Y            C
# 3        Y      M  2. Some College     354151  2_<=25      Y            B
# 4        Y      F  2. Some College     117087   1_Unk      Y            J
# ...    ...    ...              ...        ...     ...    ...          ...
# 39995    Y      F          3. Bach          0   7_>65      Y            C
# 39996    N      F            1. HS     213596  4_<=45      N            I
# 39997    Y      M           0. <HS     134070  3_<=35      Y            F
# 39998    N      M            1. HS     402210   7_>65      Y            E
# 39999    N      F          3. Bach     836030   7_>65      Y            B
#
#       marriage child     occupation mortgage house_owner     region  car_prob  \
# ...

# %%
pivot=data.pivot_table(index='gender' ,columns='education',values='age',aggfunc='count')

# %%
pivot
# Out:
# education  0. <HS  1. HS  2. Some College  3. Bach  4. Grad
# gender
# F            1641   4474             4842     3704     1943
# M            1992   4116             6254     5373     3810
# U             215    238              304      190      163

# %%
import seaborn as sns

# %%
sns.heatmap(pivot)
# Out:
# <Axes: xlabel='education', ylabel='gender'>

# %%
data.pivot_table(index=['gender','occupation'] ,columns='education',values='age',aggfunc='count')
# Out:
# education             0. <HS   1. HS  2. Some College  3. Bach  4. Grad
# gender occupation
# F      Blue Collar     225.0   721.0            585.0    178.0     66.0
#        Farm             19.0    22.0             25.0      7.0      3.0
#        Others           76.0   195.0            189.0     94.0     42.0
#        Professional    256.0   840.0           1570.0   2161.0   1268.0
#        Retired         358.0   910.0            316.0    352.0     96.0
#        Sales/Service   707.0  1786.0           2157.0    912.0    468.0
# M      Blue Collar     703.0  1490.0           1593.0    533.0    260.0
#        Farm             54.0    51.0             83.0     41.0     11.0
#        Others          115.0   231.0            360.0    202.0    134.0
#        Professional    306.0   706.0           1982.0   3091.0   2339.0
#        Retired         360.0   647.0            359.0    400.0    450.0
#        Sales/Service   454.0   991.0           1877.0   1106.0    616.0
# ...
