# %% [markdown]
# ## Pandas libraries

# %%
import  pandas as pd

# %%
data=pd.read_csv('Overseas.csv')

# %%
data.shape
# Out:
# (118, 9)

# %%
data.head()
# Out:
#                 Country                                 Article Continent  \
# 0          Saudi Arabia              Pakistanis in Saudi Arabia      Asia
# 1  United Arab Emirates  Pakistanis in the United Arab Emirates      Asia
# 2                  Oman                      Pakistanis in Oman      Asia
# 3                 Qatar                     Pakistanis in Qatar      Asia
# 4               Bahrain                   Pakistanis in Bahrain      Asia
#
#    Overseas Pakistani population (By Country)       Extra Information  \
# 0                                     2600000                     NaN
# 1                                     1500000                     NaN
# 2                                      231685  2016 official estimate
# 3                                      125000           2016 estimate
# 4                                      117000                     NaN
#
#   Overseas Pakistani Population by Continent  Population (by Continent)  \
# ...

# %%
data.tail()
# Out:
#            Country                      Article Continent  \
# 113     Seychelles     Pakistanis in Seychelles    Africa
# 114         Guinea         Pakistanis in Guinea    Africa
# 115  Guinea Bissau  Pakistanis in Guinea Bissau    Africa
# 116      Australia         Pakistani Australian   Oceania
# 117    New Zealand      Pakistani New Zealander   Oceania
#
#      Overseas Pakistani population (By Country)  \
# 113                                          27
# 114                                          10
# 115                                          10
# 116                                       64346
# 117                                        3261
#
#                     Extra Information  \
# 113                               NaN
# 114                               NaN
# 115                               NaN
# 116           according to 2016 data
# 117  2013 Official New Zealand Census
#
#     Overseas Pakistani Population by Continent  Population (by Continent)  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 9 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country                                     118 non-null    object
#  1   Article                                     118 non-null    object
#  2   Continent                                   118 non-null    object
#  3   Overseas Pakistani population (By Country)  118 non-null    int64
#  4   Extra Information                           26 non-null     object
#  5   Overseas Pakistani Population by Continent  6 non-null      object
#  6   Population (by Continent)                   6 non-null      float64
#  7   Year                                        46 non-null     float64
#  8    Remittance ($ billion)                     46 non-null     float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 8.4+ KB

# %%
data.describe()
# Out:
#        Overseas Pakistani population (By Country)  Population (by Continent)  \
# count                                1.180000e+02               6.000000e+00
# mean                                 6.689296e+04               2.916742e+06
# std                                  2.998908e+05               3.372078e+06
# min                                  5.000000e+00               6.760700e+04
# 25%                                  1.105000e+02               5.521470e+05
# 50%                                  7.125000e+02               1.739984e+06
# 75%                                  1.150000e+04               4.151952e+06
# max                                  2.600000e+06               8.840732e+06
#
#               Year   Remittance ($ billion)
# count    46.000000                46.000000
# mean   1998.500000                 6.856126
# std      13.422618                 8.016604
# min    1976.000000                 0.412000
# 25%    1987.250000                 1.607025
# ...

# %% [markdown]
# ## how to fetch multiple columns in data set

# %%
data["Country"]
# Out:
# 0              Saudi Arabia
# 1      United Arab Emirates
# 2                      Oman
# 3                     Qatar
# 4                   Bahrain
#                ...
# 113              Seychelles
# 114                  Guinea
# 115           Guinea Bissau
# 116               Australia
# 117             New Zealand
# Name: Country, Length: 118, dtype: object

# %%
data[["Country","Continent","Overseas Pakistani population (By Country)"]]
# Out:
#                   Country Continent  \
# 0            Saudi Arabia      Asia
# 1    United Arab Emirates      Asia
# 2                    Oman      Asia
# 3                   Qatar      Asia
# 4                 Bahrain      Asia
# ..                    ...       ...
# 113            Seychelles    Africa
# 114                Guinea    Africa
# 115         Guinea Bissau    Africa
# 116             Australia   Oceania
# 117           New Zealand   Oceania
#
#      Overseas Pakistani population (By Country)
# 0                                       2600000
# 1                                       1500000
# 2                                        231685
# 3                                        125000
# 4                                        117000
# ..                                          ...
# 113                                          27
# 114                                          10
# 115                                          10
# ...

# %%
data.iloc[0]
# Out:
# Country                                                     Saudi Arabia
# Article                                       Pakistanis in Saudi Arabia
# Continent                                                           Asia
# Overseas Pakistani population (By Country)                       2600000
# Extra Information                                                    NaN
# Overseas Pakistani Population by Continent                          Asia
# Population (by Continent)                                      4827032.0
# Year                                                              1976.0
#  Remittance ($ billion)                                            0.412
# Name: 0, dtype: object

# %%
data.iloc[1:6:2]
# Out:
#                 Country                                 Article Continent  \
# 1  United Arab Emirates  Pakistanis in the United Arab Emirates      Asia
# 3                 Qatar                     Pakistanis in Qatar      Asia
# 5                Kuwait                    Pakistanis in Kuwait      Asia
#
#    Overseas Pakistani population (By Country)       Extra Information  \
# 1                                     1500000                     NaN
# 3                                      125000           2016 estimate
# 5                                      109853  2016 official estimate
#
#   Overseas Pakistani Population by Continent  Population (by Continent)  \
# 1                                   Americas                  1353255.0
# 3                                     Africa                   285111.0
# 5        Total overseas Pakistani population                  8840732.0
#
#      Year   Remittance ($ billion)
# 1  1977.0                   0.8721
# ...

# %%
data.iloc[[2,5,6]]
# Out:
#     Country                 Article Continent  \
# 2      Oman      Pakistanis in Oman      Asia
# 5    Kuwait    Pakistanis in Kuwait      Asia
# 6  Malaysia  Pakistanis in Malaysia      Asia
#
#    Overseas Pakistani population (By Country)       Extra Information  \
# 2                                      231685  2016 official estimate
# 5                                      109853  2016 official estimate
# 6                                       59281  2017 official estimate
#
#   Overseas Pakistani Population by Continent  Population (by Continent)  \
# 2                                     Europe                  2126713.0
# 5        Total overseas Pakistani population                  8840732.0
# 6                                        NaN                        NaN
#
#      Year   Remittance ($ billion)
# 2  1978.0                   1.3093
# 5  1981.0                   2.0671
# 6  1982.0                   2.5881

# %%
data.iloc[:,[1,4,8]]
# Out:
#                                     Article                 Extra Information  \
# 0                Pakistanis in Saudi Arabia                               NaN
# 1    Pakistanis in the United Arab Emirates                               NaN
# 2                        Pakistanis in Oman            2016 official estimate
# 3                       Pakistanis in Qatar                     2016 estimate
# 4                     Pakistanis in Bahrain                               NaN
# ..                                      ...                               ...
# 113                Pakistanis in Seychelles                               NaN
# 114                    Pakistanis in Guinea                               NaN
# 115             Pakistanis in Guinea Bissau                               NaN
# 116                    Pakistani Australian           according to 2016 data
# 117                 Pakistani New Zealander  2013 Official New Zealand Census
#
#       Remittance ($ billion)
# ...
